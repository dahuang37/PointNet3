# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
from os.path import basename, splitext

BASE_DIR = os.getcwd() 
sys.path.append(BASE_DIR)
sys.path.append(os.path.join(BASE_DIR, 'utils'))

import dataset
import data_visualization

# %%
data, label = dataset.getAllTrainingData()
shape_names = dataset.getShapeNames()
file_list = dataset.get3DList()
filename = basename(splitext(file_list[483])[0])
mesh = "data/ModelNet40/guitar/train/guitar_0035.off"
data_visualization.draw_mesh(mesh)
# Out:
# (9840,)
# cone_0080
# [9]
# (9840, 2048, 3)

# %%
## print a example image for each class
for i in range(40):
    index, _ = np.where(label==i)
    images = data[index]
    print("Shape: %s %d \n"%(shape_names[i], i))
    #data_visualization.pyplot_draw_point_cloud(images[0],"")
# Out:
# Shape: airplane 0
#
# Shape: bathtub 1
#
# Shape: bed 2
#
# Shape: bench 3
#
# Shape: bookshelf 4
#
# Shape: bottle 5
#
# Shape: bowl 6
#
# Shape: car 7
#
# Shape: chair 8
#
# Shape: cone 9
#
# Shape: cup 10
#
# Shape: curtain 11
#
# Shape: desk 12
#
# Shape: door 13
#
# Shape: dresser 14
#
# Shape: flower_pot 15
#
# Shape: glass_box 16
#
# Shape: guitar 17
#
# Shape: keyboard 18
#
# Shape: lamp 19
#
# Shape: laptop 20
#
# Shape: mantel 21
#
# Shape: monitor 22
#
# Shape: night_stand 23
#
# Shape: person 24
#
# Shape: piano 25
#
# Shape: plant 26
#
# Shape: radio 27
#
# Shape: range_hood 28
#
# Shape: sink 29
#
# Shape: sofa 30
#
# Shape: stairs 31
#
# Shape: stool 32
#
# Shape: table 33
#
# Shape: tent 34
#
# Shape: toilet 35
#
# Shape: tv_stand 36
#
# Shape: vase 37
#
# Shape: wardrobe 38
#
# Shape: xbox 39

# %%
index, _ = np.where(label==10)
images = data[index]

mean_images = np.mean(images, axis=0)
shape_name_idx = file_list[index]

print(shape_name_idx[1])

data_visualization.pyplot_draw_point_cloud(images[1],"20_mean")
data_visualization.pyplot_draw_point_cloud(mean_images,"20_mean")
# Out:
# cup/cup_0045.ply
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
